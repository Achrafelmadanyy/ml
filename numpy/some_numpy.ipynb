# %%
import numpy as np
import random

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
a=np.eye(3)

# %%
np.full((3,3),1)
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]])

# %%
np.linspace(1,100,12)
# Out:
# array([  1.,  10.,  19.,  28.,  37.,  46.,  55.,  64.,  73.,  82.,  91.,
#        100.])

# %%
a=np.eye(3)
a[:,1]=[1,2,3]
a
# Out:
# array([[1., 1., 0.],
#        [0., 2., 0.],
#        [0., 3., 1.]])

# %%
np.random.seed(2)
np.random.rand(3,3)
# Out:
# array([[0.4359949 , 0.02592623, 0.54966248],
#        [0.43532239, 0.4203678 , 0.33033482],
#        [0.20464863, 0.61927097, 0.29965467]])

# %%
np.random.seed(5)
np.random.randint(low=1, high=10,size=(3,3))
# Out:
# array([[4, 7, 7],
#        [1, 9, 5],
#        [8, 1, 1]])

# %%
a=np.arange(6)
b=np.arange(1,7)
print(a)
random.shuffle(b)
b
# Out:
# [0 1 2 3 4 5]
# array([4, 5, 1, 2, 3, 6])

# %%
np.arange(6)>=2
# Out:
# array([False, False,  True,  True,  True,  True])

# %%
np.arange(6)>2
# Out:
# array([False, False, False,  True,  True,  True])

# %%
help(random.shuffle)
# Out:
# Help on method shuffle in module random:
#
# shuffle(x) method of random.Random instance
#     Shuffle list x in place, and return None.

# %%
b[b>=a]
# Out:
# array([4, 5, 6])

# %%
I=np.eye(3)
B=I+68*np.random.rand(3,3)

# %%
A=10*np.random.rand(3,3)

# %%
(I+A)@B
# Out:
# array([[ 83.09281429,   1.07639948, 336.57998961],
#        [ 81.97181568,  28.79994562,  36.03989827],
#        [381.90317795, 461.4168987 ,  26.17676792]])
